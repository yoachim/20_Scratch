# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from lsst.sims.utils import m5_flat_sed

# %%
expt = np.arange(1,120, 1)

# %%
m5 = m5_flat_sed('r', 23.28, 0.7, expt, 1.1)

# %%
plt.semilogx(expt, m5)
